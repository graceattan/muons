# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("lifetimes.txt", sep=" ", header=None)
df.columns = ["RE0_time", "RE0_bits", "RE1_time", "RE1_bits", "lifetimes"]
df
# Out:
#       RE0_time  RE0_bits  RE1_time  RE1_bits  lifetimes
# 0     591EA73D         1  591EA73E       100     358.75
# 1     5F09A2BE      1010  5F09A2BE      1111     321.25
# 2     F038D58D        11  F038D58E         1      20.00
# 3     F309594F     11001  F309596A      1110  -80501.25
# 4     021B76CF     10010  021B78BB     11101   25101.25
# ...        ...       ...       ...       ...        ...
# 4185  4686B960       101  4686B961     10010   81658.75
# 4186  7D3476CA        11  7D3476CB      1010    5158.75
# 4187  FA6F2076     10111  FA6F2077     10001    -300.00
# 4188  706CE088     10001  706CE089     11100    5478.75
# 4189  7972EB9F     10000  7972EB9F     11001    5121.25
#
# [4190 rows x 5 columns]

# %%
hist = df['lifetimes'].hist(bins=20)
hist.set_xlabel("Lifetime Ranges")
hist.set_ylabel("Frequency")
plt.show()
