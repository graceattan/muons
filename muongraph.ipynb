# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("lifetimes.txt", sep=" ", header=None)
df.columns = ["RE0_time", "RE0_bits", "RE1_time", "RE1_bits", "lifetimes"]
df
# Out:
#      RE0_time  RE0_bits  RE1_time  RE1_bits  lifetimes
# 0    F309594F     11001  F309596A      1110    1066.25
# 1    021B76CF     10010  021B78BB     11101   19693.75
# 2    EE88DC21     10110  EE88DC79     10010    3515.00
# 3    9A359A89        11  9A359AB0     10011    1580.00
# 4    19E450EC     10001  19E451A9      1001    7550.00
# ..        ...       ...       ...       ...        ...
# 410  F54FEAB0        10  F54FEAC8      1101     973.75
# 411  2EC8D552       101  2EC8D593     10110    2621.25
# 412  60E2481E       111  60E24830     10111     740.00
# 413  7261F6FD      1001  7261F863     11101   14345.00
# 414  FBBE867F       101  FBBE86D8       111    3562.50
#
# [415 rows x 5 columns]

# %%
hist = df['lifetimes'].hist(bins=100)
hist.set_xlabel("Lifetime Ranges")
hist.set_ylabel("Frequency")
plt.show()
